# %%
import pandas as pd

# %%
episodes = pd.read_html('https://en.wikipedia.org/wiki/List_of_Rick_and_Morty_episodes')
episodes[2]
# Out:
#    No.overall  No. inseason                                      Title  \
# 0          12             1                         "A Rickle in Time"
# 1          13             2                           "Mortynight Run"
# 2          14             3                 "Auto Erotic Assimilation"
# 3          15             4                            "Total Rickall"
# 4          16             5                             "Get Schwifty"
# 5          17             6                  "The Ricks Must Be Crazy"
# 6          18             7            "Big Trouble in Little Sanchez"
# 7          19             8  "Interdimensional Cable 2: Tempting Fate"
# 8          20             9                   "Look Who's Purging Now"
# 9          21            10                   "The Wedding Squanchers"
#
#        Directed by                                  Written by  \
# 0       Wes Archer                                 Matt Roller
# ...
